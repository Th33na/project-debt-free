# %%
import pandas as pd

df = pd.read_csv("cc_transactions_reduced.csv")
                 
df.head()
# Out:
#    User  Card  Year  Month  Day   Time  Amount          Use Chip  \
# 0     0     0  2016      1    3  10:48  $66.48  Chip Transaction
# 1     0     0  2016      1    4  06:43  $40.02  Chip Transaction
# 2     0     0  2016      1    7  09:30  $54.11  Chip Transaction
# 3     0     0  2016      1    7  16:03  $89.48  Chip Transaction
# 4     0     0  2016      1   10  06:38  $29.15  Chip Transaction
#
#          Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0 -3345936507911876459       La Verne             CA  91750.0  7538     NaN
# 1   -34551508091458520       La Verne             CA  91750.0  5912     NaN
# 2  4055257078481058705       La Verne             CA  91750.0  7538     NaN
# 3  3414527459579106770  Monterey Park             CA  91754.0  5651     NaN
# 4 -5475680618560174533  Monterey Park             CA  91755.0  5942     NaN
#
#   Is Fraud?
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
